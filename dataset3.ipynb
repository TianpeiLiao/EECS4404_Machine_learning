# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import time
import random

# %% [markdown]
# # Download data

# %%
# Fetch MNIST dataset
from sklearn.datasets import fetch_openml

# data_set = 'mnist'
data_set = 'fashion_mnist'

if data_set == 'mnist':
  raw_data = fetch_openml('mnist_784')
  raw_data_x = np.array((raw_data['data']+0.5)/256.0)
  raw_data_y = np.array(raw_data['target'].astype('int8'))
  num_classes = 10
  img_sz = (28,28)
elif data_set == 'fashion_mnist':
  raw_data = fetch_openml('Fashion-MNIST')
  raw_data_x = np.array((raw_data['data']+0.5)/256.0)
  raw_data_y = np.array(raw_data['target'].astype('int8'))
  num_classes = 10
  img_sz = (28,28)
else:
  assert False

data_dim = raw_data_x.shape[1]

# %% [markdown]
# ## Split data into training and validation

# %%
def display_image(x,lbl=None):
  plt.imshow(x.reshape(img_sz))
  plt.xticks([])
  plt.yticks([])
  if lbl is not None:
    plt.title(lbl)

def split_data(x,y,fracs=[0.8,0.2],seed=0):
  if seed is not None:
    np.random.seed(seed)
  N = x.shape[0]
  rp = np.random.permutation(N)

  N1 = int(fracs[0]*N)
  N2 = min(N-N1,int(fracs[1]*N))

  # Split the data into two parts
  x1 = x[rp[:N1]]
  y1 = y[rp[:N1]]
  x2 = x[rp[N1:(N1+N2)]]
  y2 = y[rp[N1:(N1+N2)]]

  return x1,y1,x2,y2

def onehot_encode(y,num_classes=10):
  """
  Convert an Nx1 vector of integer class labels from 0 to C-1 into 
  an NxC matrix where each row is a one-hot encoding of the 
  """
  return np.eye(num_classes)[y.reshape(-1)]

# %%
train_x,train_y,test_x,test_y = split_data(raw_data_x,raw_data_y,fracs=[0.2,0.2])
train_x,train_y,  val_x,val_y = split_data(train_x,train_y,fracs=[0.6,0.4])

# %% [markdown]
# # Explore the data

# %%
# Print statistics
num_train = len(train_y)
for i in range(num_classes):
  num_class_i = np.sum(train_y == i)
  print('{:.2f}% of the training data is class {}, corresponding to {} data points'.format(100*num_class_i/num_train,
                                                                                       i, num_class_i))

# Visualize a few images
np.random.seed(0)
num_digits = 10
num_rows = 3
plt.figure(figsize=(10,5))
for i in range(num_rows*num_digits):
  ind = np.random.randint(0,train_x.shape[0])
  plt.subplot(num_rows,num_digits,i+1)
  display_image(train_x[ind,:],
                train_y[ind])
# Out:
# 10.77% of the training data is class 0, corresponding to 905 data points
# 10.32% of the training data is class 1, corresponding to 867 data points
# 9.39% of the training data is class 2, corresponding to 789 data points
# 10.48% of the training data is class 3, corresponding to 880 data points
# 9.73% of the training data is class 4, corresponding to 817 data points
# 9.76% of the training data is class 5, corresponding to 820 data points
# 10.49% of the training data is class 6, corresponding to 881 data points
# 9.61% of the training data is class 7, corresponding to 807 data points
# 9.33% of the training data is class 8, corresponding to 784 data points
# 10.12% of the training data is class 9, corresponding to 850 data points

# %% [markdown]
# # Implement activation and loss functions and their derivatives

# %%
def sigmoid(a,deriv=False):
  # The sigmoid activation function 1/(1+exp(-a)) and its derivative
  #
  # Input: a - NxC matrix of values where each row of a corresponds to a single
  # input to the current layer with C units.
  # Output: s,ds
  #   s - NxC matrix of sigmoid function evaluated at the values in a
  #  ds - NxC matrix of the derivatives of the sigmoid evaluated at the values of a
  #
  # NOTE: you may only use basic exp/log functions from numpy here.  Only
  # np.exp, np.log, np.log1p, np.log1m, along with basic arithmetic are allowed
  # in your implementation.

  s  = 1/(1.0 + np.exp(-a))

  if deriv:
    ns = 1/(1.0 + np.exp( a))
    ds = s*ns

    return s, ds
  else:
    return s

def relu(a,deriv=False):
  # TODO: Implement the relu activation function max(a,0) and its derivative
  #
  # Input: a - NxC matrix of values where each row of a corresponds to a single
  # input to the current layer with C units.
  # Output: r,dr
  #   r - NxC matrix of function values at the values in a
  #  dr - NxC matrix of the derivatives of the relu evaluated at the values of a
  r = np.copy(a)
  r[r<0] = 0
  #r = np.zeros(a.shape)
  dr = np.copy(r)
  dr[dr>0] = 1
  dr[dr<0] = 0
  
  if deriv:
    return r, dr
  else:
    return r

def softmax(a,params=None,deriv=False):
  # TODO: Implement the softmax function s = exp(a)/sum(exp(a)) and its
  # Jacobian where J[i,j] = ds[i]/da[j] = -(s[i]*s[j]) if i!=j and
  # (s[i]*(1-s[i])) if i==j.
  #
  # Input: a - NxC matrix of values where each row of a corresponds to a single
  # input to the softmax function
  # Output: s,ds
  #   s - NxC matrix of softmax function values at the values in a
  #  ds - NxCxC tensor of Jacobians of the softmax function of each input

  N,C = a.shape

  s = np.zeros((N,C))
  for i in range(N):
    local_max = np.max(a[i])
    sum = 0
    for j in a[i]:
      sum = sum + np.exp(j-local_max)
    for k in range(len(a[i])):
      s[i][k] = np.exp(a[i][k] - local_max)/sum

  if deriv:
    #print("s:{}".format(s))
    ds = np.zeros((N,C,C))
    for n in range(N):
      for i in range(C):
          for j in range(C):
              if i == j:
                  ds[n][i][j] = s[n][i] * (1-s[n][i])
              else: 
                  ds[n][i][j] = -s[n][i]*s[n][j]

    return s, ds
  else:
    return s

def identity(a,deriv=False):
  if deriv:
    return a, np.ones_like(a)
  else:
    return a

def crossent(y,yhat,deriv=False):
  # TODO: Implement the cross entropy loss L = -\sum_c (y==c) log(p(y==c)).
  #
  # Input: y,yhat
  #     y - Nx1 vector of class labels for N inputs
  #  yhat - NxC matrix of probabilities of each class c for each input i
  #         i.e., yhat[i,c] is p(y[i]==c)
  #
  # Output: l,dl
  #   l - Nx1 vector of cross entropy values
  #  dl - Nx1xC matrix of derivatives
  N,C = yhat.shape
  assert y.shape[0] == N
  one_hot = onehot_encode(y)
  
  #print("y:{}".format(y))
  #print("one_hot:{}".format(one_hot))
  l = np.zeros(N)
  for i in range(N):
    sum = 0
    for j in range(C):
      sum-= one_hot[i][j]*np.log(yhat[i][j])
    l[i] = sum
    
  if deriv:
    dl = yhat - one_hot

    return l,dl
  else:
    return l

def test_acts_impl():
  # These are sanity checks, not exhaustive unit tests.  These may pass but you
  # may still have bugs.  However, if these don't pass you almost certainly have
  # bugs.

  import scipy.special as spsp

  acts = [sigmoid,relu,softmax,identity]
  N = 2
  D = 5
  eps = 1e-8
  for _ in range(5):
    aval0 = np.random.randn(N,D)
    for afunc in acts:
      fval, dfval = afunc(aval0,deriv=True)
      print(afunc) # uncomment this line to see which activation function is failing
      for i in range(D):
        aval_m = np.copy(aval0)
        aval_m[:,i] -= eps
        aval_p = np.copy(aval0)
        aval_p[:,i] += eps

        dfval_fd = (afunc(aval_p) - afunc(aval_m))/(2*eps)
        if dfval.ndim == 3:
          assert np.allclose(dfval_fd,dfval[:,:,i])
        else:
          #print("dfval_fd:{}".format(dfval_fd))
          #print("dfval:{}".format(dfval))
          assert np.allclose(dfval_fd[:,i],dfval[:,i])
  
  # unit test the sigmoid function
  eps = 1e-8
  avals = [-5,0.1,1]
  for a in avals:
    sa = sigmoid(a)

    assert np.all(sa > 0)
    assert np.all(sa < 1)
    assert np.abs(sa - spsp.expit(a)) < 1e-8

  # unit test the softmax function
  N = 2
  D = 5
  eps = 1e-8
  logitval0 = np.random.randn(N,D)
  s0 = softmax(logitval0)
  assert np.all(s0 >= 0)
  assert np.all(np.abs(1-np.sum(s0,axis=1))<1e-8)


  ina = np.linspace(-10,10,1000)
  plt.figure()
  plt.subplot(1,2,1)
  plt.plot(ina,sigmoid(ina,deriv=False))
  plt.title('$\sigma(a)$')
  plt.subplot(1,2,2)
  plt.plot(ina,sigmoid(ina,deriv=True)[1])
  plt.title('$d \sigma(a)$')

  ina = np.linspace(-10,10,1000)
  plt.figure()
  plt.subplot(1,2,1)
  plt.plot(ina,relu(ina,deriv=False))
  plt.title('$relu(a)$')
  plt.subplot(1,2,2)
  plt.plot(ina,relu(ina,deriv=True)[1])
  plt.title('$d relu(a)$')

test_acts_impl()
# Out:
# <function sigmoid at 0x7f6d3db8db90>
# <function relu at 0x7f6ce244d560>
# <function softmax at 0x7f6d3db8df80>
# <function identity at 0x7f6d3db15b90>
# <function sigmoid at 0x7f6d3db8db90>
# <function relu at 0x7f6ce244d560>
# <function softmax at 0x7f6d3db8df80>
# <function identity at 0x7f6d3db15b90>
# <function sigmoid at 0x7f6d3db8db90>
# <function relu at 0x7f6ce244d560>
# <function softmax at 0x7f6d3db8df80>
# <function identity at 0x7f6d3db15b90>
# <function sigmoid at 0x7f6d3db8db90>
# <function relu at 0x7f6ce244d560>
# <function softmax at 0x7f6d3db8df80>
# <function identity at 0x7f6d3db15b90>
# <function sigmoid at 0x7f6d3db8db90>
# <function relu at 0x7f6ce244d560>
# <function softmax at 0x7f6d3db8df80>
# <function identity at 0x7f6d3db15b90>

# %% [markdown]
# # Implement forward pass and backprop

# %%
def nn_forward(x,acts,Theta):
  """
  Compute the forward pass of a neural network model for a set of inputs.

  Input: x,loss,acts,Theta,deriv
    x - NxD matrix of input vectors
    acts - list of length L of activation functions for each layer
    Theta - list of length L of the parameters of each layer.  In general, 
            Theta[i] = (Wi,bi) where Wi and bi are the weight matrix and bias 
            vector for layer i.

  Output: z
    z - an NxC matrix where C is the dimensionality of the output
  """
  N = x.shape[0]
  num_layers = len(acts)
  z = x

  for i in range(num_layers):
    act = acts[i] # activation function at this layer
    Wi,bi = Theta[i] # parameters at this layer 

    ai = (Wi @ z.T + bi).T
    z = act(ai,deriv=False)

  return z

def nn_loss(x,y,loss,acts,Theta,deriv=False):
  """
  Compute the objective function (and gradients) of the loss function for a set
  of data using a neural network model.

  Input: x,y,loss,acts,Theta,deriv
    x - NxD matrix of input vectors
    y - Nx1 vector of ground truth labels
    loss - function handle for the loss function
    acts - list of length L of activation functions for each layer
    Theta - list of length L of the parameters of each layer.  In general, 
            Theta[i] = (Wi,bi) where Wi and bi are the weight matrix and bias 
            vector for layer i.
    deriv - whether or not to compute and do the derivative

  Output: if deriv: E, dEdTheta, acc
              else: E, acc
    E - value of the loss function
    dEdTheta - the derivatives of the loss function for the parameters in Theta
               it has the same layout as Theta, specifically, 
                 dEdTheta[i] = (dEdWi,dEdbi) is the
               derivative of E with respect to the weight matrix and bias vector
               of layer i.
    acc - accuracy of predictions on the given data
  """
  N = x.shape[0]
  num_layers = len(acts)
  z = x

  zs = [] # input and output of each layer
  dzi_dais = [] # derivative of activation function of each layer
  for i in range(num_layers):
    act = acts[i] # activation function at this layer
    Wi,bi = Theta[i] # parameters at this layer 

    ai = (Wi @ z.T + bi).T
    if deriv:
      zs.append(z) # store input to the layer, needed for derivative wrt W

      z, dzi_dai = act(ai,deriv=True)
      dzi_dais.append(dzi_dai) # store derivative of activation function
    else:
      z = act(ai,deriv=False)

  maxc = np.argmax(z,axis=1) # Index of class with maximum probability
  acc = np.sum(maxc == y)/N

  if deriv:
    L, dLdz = loss(y,z,deriv=True)
    E = np.mean(L)

    dEdTheta = [None]*len(acts)

    # Initialize backprop with the gradients of the loss values wrt to the
    # output of the last layer
    # 
    # dLdzi has shape Nx1xDi where Di is the dimensionality of layer i because
    # we are treating it as the Jacobian of a function with 1 output
    dLdzi = (1.0/N)*dLdz

    # Backward pass
    for i in reversed(range(num_layers)):
      act = acts[i] # activation function at this layer
      Wi,bi = Theta[i] # parameters at this layer 
      zi_1 = zs[i] # input to the current layer
      dzi_dai = dzi_dais[i] # derivatives of layer activation function

      Di, Di_1 = Wi.shape
      # TODO: Backpropogate the derivative dLdzi through the activation function 
      # to compute dLdai.
      if dzi_dai.ndim == 2:
        # If dzi_dai only has two dimensions, then this activation function is 
        # element wise, so we only need to multiply each element of dLdzi with
        # it's corresponding derivative in dzi_dai.
        dLdai = dLdzi * dzi_dai
      else:
        # If dzi_dai only has three dimensions, then this activation function is 
        # not elementwise and has a full Jacobian so we need to multiply the
        # jacobians dLzi[i] (a 1xDi matrix) and dzi_dai[i] (a DixDi matrix) for
        # each data point i.  For efficiency try to avoid looping by using the
        # @ operator and/or the np.matmul function.
        dLdai = N,D,C = dzi_dai.shape
        dLdai = np.zeros((N,D))
        for j in range(len(dzi_dai)):
          dLdai[j] = np.matmul(dLdzi[j],dzi_dai[j])

      # TODO: Backpropogate the derivative dLdai through the linear
      # transformation to compute dLdzi for the next layer.
      dLdzi = np.matmul(dLdai,Wi)

      # Derivatives of the parameters of the linear layer
      dEdW = np.sum(dLdai.reshape((N,Di,1)) * zi_1.reshape((N,1,Di_1)),axis=0)
      dEdb = np.sum(dLdai.reshape((N,Di)),axis=0).reshape((Di,1))
      dEdTheta[i] = (dEdW,dEdb)

    return E, dEdTheta, acc
  else:
    L = loss(y,z,deriv=False)
    E = np.mean(L)
    return E, acc

# %% [markdown]
# ## Implement network training with SGD

# %%
def nn_fit(train_x, train_y, val_x, val_y,
           opt_params, arch_params):
  """
  Train a neural network using stochastic gradient descent.

  Inputs: train_x, train_y, val_x, val_y, opt_params, arch_params
    train_x - NxD matrix of full training set with N samples and D dimensions
    train_y - Nx1 vector of training output values
    val_x, val_y - a validation set of samples to monitor performance
    opt_params - parameters of the training algorithm (see below)
    arch_params - parameters of the neural network architecture (see below)
  
  Outputs: Theta, stats
    Theta - parameters at the end of optimization
    stats - dictionary of various statistics computed during training to be used
            for visualization and analysis
  """

  # Optimization parameters in opt_params
  batch_sz = opt_params['batch_sz'] # minibatch size to use at each iteration
  epsilon0 = opt_params['epsilon0'] # starting learning rate for SGD
  epsilon_decay = opt_params['epsilon_decay'] # decay factor for SGD learning rate
  num_its = opt_params['num_its'] # number of iterations to run
  Theta0 = opt_params['Theta0'] # initial value for the parameters, can be None to randomly initialize
  check_freq = opt_params['check_freq'] # how frequently to compute and print out statistics of learning
  print_checks = opt_params['print_checks'] # print info out when checkpointing
  seed = opt_params['seed'] if 'seed' in opt_params else 0

  if seed is not None:
    np.random.seed(seed)

  # Neural Network architecture parameters in arch_params
  num_hidden_layers = arch_params['num_hidden_layers'] # number of hidden layers
  num_hidden_units = arch_params['num_hidden_units'] # number of units per hidden layer (all layers are assumed to have the same number)
  num_outs = arch_params['num_outs'] # number of outputs, for classification the number of classes
  act_func = arch_params['act_func'] # hidden layer activation function
  out_func = arch_params['out_func'] # output layer activation function
  loss_func = arch_params['loss_func'] # loss function to use for training

  train_N, data_dim = train_x.shape

  assert num_hidden_layers >= 0
  acts = [act_func]*num_hidden_layers + [out_func]
  if Theta0 is None:
    # If no initial value of parameters is given, this randomly generates one.
    if num_hidden_layers > 1:
      Theta0 = [    (0.1*np.random.randn(num_hidden_units,data_dim),      np.zeros((num_hidden_units,1))) ] + \
               [ (0.1*np.random.randn(num_hidden_units,num_hidden_units), np.zeros((num_hidden_units,1))) ]*(num_hidden_layers-1) + \
               [    (0.1*np.random.randn(num_outs,num_hidden_units),              np.zeros((num_outs,1))) ]
    elif num_hidden_layers == 1:
      Theta0 = [ (0.1*np.random.randn(num_hidden_units,data_dim), np.zeros((num_hidden_units,1))) ] + \
               [ (0.1*np.random.randn(num_outs,num_hidden_units),         np.zeros((num_outs,1))) ]
    elif num_hidden_layers == 0:
      Theta0 = [ (0.1*np.random.randn(num_outs,data_dim),   np.zeros((num_outs,1))) ]

  check_its = []
  check_times = []
  it_times = []
  data_pts = []
  check_data_pts = []
  check_Thetas = []
  train_losss = []
  train_accs = []
  batch_losss = []
  batch_accs = []
  val_losss = []
  val_accs = []
  epsilon = epsilon0
  start_t = time.time()
  num_data_proc = 0
  Theta = Theta0
  for it in range(num_its):
    # TODO: Randomly select a subset of batch_sz training samples.  batch_inds
    # should an array of length batch_sz which contains integers with values in 0 to train_N-1
    #print("batch_sz:{}".format(train_N))
    batch_inds = np.zeros(batch_sz,dtype=int)
    random_i = random.randint(0,train_N-(batch_sz+2))
    for i in range(batch_sz):
      batch_inds[i] = random_i
      random_i = random_i+1
    
    batch_x, batch_y = train_x[batch_inds,:], train_y[batch_inds]
    batch_loss, dEdTheta, batch_acc = nn_loss(batch_x,batch_y,loss_func,acts,Theta,deriv=True)
    num_data_proc += batch_sz

    nrmsq_dEdTheta = 0
    Theta1 = []
    # Loop over all layers and update their parameters with the SGD update
    for (Wi,bi),(dEdWi,dEdbi) in zip(Theta,dEdTheta):
      # TODO: Wi1 and bi1 should be the value of the parameters after the
      # gradient update based on the derivatives dEdWi,dEdbi, previous
      # parameter values Wi,bi and stepsize epsilon
      Wi1 = Wi- dEdWi*epsilon
      bi1 = bi - dEdbi*epsilon

      Theta1.append((Wi1,bi1))

      # Compute the norm of the entire gradient to monitor
      nrmsq_dEdTheta += np.sum(dEdWi**2) + np.sum(dEdbi**2)

    # Replace old value of Theta with new one
    Theta = Theta1

    # Gradually decrease epsilon to ensure convergence of SGD
    epsilon *= epsilon_decay

    if it%check_freq == 0 or it+1 == num_its:
      # Periodically compute the training loss/accuracy on the _full_ dataset
      # for reference.  Note this is rarely done in practice because it isn't
      # possible or is hugely impractical.  We're just doing it here to see 
      # how it relates to the values computed with a mini-batch
      train_loss, train_acc = nn_loss(train_x,train_y,
                                   loss_func,acts,Theta,deriv=False)


      # Periodically compute the validation loss/accuracy for reference.
      val_loss, val_acc = nn_loss(val_x,val_y,
                               loss_func,acts,Theta,deriv=False)

      check_Thetas.append(Theta)
      check_its.append(it)
      check_data_pts.append(num_data_proc)
      check_times.append(time.time() - start_t)
      train_losss.append(train_loss)
      train_accs.append(train_acc)
      val_losss.append(val_loss)
      val_accs.append(val_acc)
      if print_checks:
        print("{:4}: eps = {:.2e};"
              "  batch: loss = {:5.2f}, acc = {:.2f};"
              "  train: loss = {:5.2f}, acc = {:.2f};"
              "  val: loss = {:5.2f}, acc = {:.2f};"
              "  ||dEdTheta|| = {:5.2f}".format(it, epsilon,
                                                batch_loss, batch_acc,
                                                train_loss, train_acc,
                                                val_loss, val_acc,
                                                np.sqrt(nrmsq_dEdTheta)))
    data_pts.append(num_data_proc)
    it_times.append(time.time() - start_t)
    batch_losss.append(batch_loss)
    batch_accs.append(batch_acc)

  stats = { 'check_its':check_its, # Iteration numbers of checkpoints
            'check_times':check_times, # wall clock time of checkpoints
            'check_data_pts':check_data_pts, # number of training samples processed at check points
            'check_Thetas':check_Thetas, # Theta values at checkpoints
            'it_times':it_times, # wall clock time of each iteration
            'data_pts':data_pts, # number of training samples processed at each iteration
            'batch_losss':batch_losss, 'batch_accs':batch_accs, # loss and accuracy of each batch
            'train_losss':train_losss, 'train_accs':train_accs, # loss and accuracy of full training set at checkpoint iterations
            'val_losss':val_losss, 'val_accs':val_accs } # loss and accuracy of validation set at checkpoint iterations
  return Theta, stats

# %% [markdown]
# ## Train a network on the dataset

# %%
opt_params = { 'batch_sz':20, 'epsilon0':1e-1, 'epsilon_decay':0.99999,
               'num_its':2001, 'check_freq':100, 'print_checks':True, 'Theta0':None }
arch_params = { 'num_hidden_layers':2, 'num_hidden_units':20, 'num_outs':num_classes,
                'act_func':relu, 'out_func':softmax, 'loss_func':crossent }

Theta, stats = nn_fit(train_x, train_y, val_x, val_y,
                      opt_params, arch_params)
# Out:
#    0: eps = 1.00e-01;  batch: loss =  2.31, acc = 0.00;  train: loss =  2.33, acc = 0.02;  val: loss =  2.34, acc = 0.02;  ||dEdTheta|| =  0.04
#  100: eps = 9.99e-02;  batch: loss =  2.28, acc = 0.25;  train: loss =  2.27, acc = 0.13;  val: loss =  2.27, acc = 0.12;  ||dEdTheta|| =  0.05
#  200: eps = 9.98e-02;  batch: loss =  2.24, acc = 0.15;  train: loss =  2.18, acc = 0.20;  val: loss =  2.19, acc = 0.19;  ||dEdTheta|| =  0.07
#  300: eps = 9.97e-02;  batch: loss =  1.93, acc = 0.25;  train: loss =  2.01, acc = 0.21;  val: loss =  2.03, acc = 0.21;  ||dEdTheta|| =  0.25
#  400: eps = 9.96e-02;  batch: loss =  1.93, acc = 0.20;  train: loss =  1.84, acc = 0.27;  val: loss =  1.86, acc = 0.26;  ||dEdTheta|| =  0.18
#  500: eps = 9.95e-02;  batch: loss =  1.54, acc = 0.40;  train: loss =  1.64, acc = 0.33;  val: loss =  1.66, acc = 0.31;  ||dEdTheta|| =  0.24
#  600: eps = 9.94e-02;  batch: loss =  1.37, acc = 0.50;  train: loss =  1.34, acc = 0.54;  val: loss =  1.35, acc = 0.53;  ||dEdTheta|| =  0.41
#  700: eps = 9.93e-02;  batch: loss =  1.30, acc = 0.45;  train: loss =  1.09, acc = 0.60;  val: loss =  1.09, acc = 0.60;  ||dEdTheta|| =  0.49
#  800: eps = 9.92e-02;  batch: loss =  1.07, acc = 0.70;  train: loss =  0.96, acc = 0.65;  val: loss =  0.96, acc = 0.65;  ||dEdTheta|| =  0.62
#  900: eps = 9.91e-02;  batch: loss =  0.99, acc = 0.70;  train: loss =  0.92, acc = 0.66;  val: loss =  0.92, acc = 0.65;  ||dEdTheta|| =  0.82
# 1000: eps = 9.90e-02;  batch: loss =  1.02, acc = 0.70;  train: loss =  0.85, acc = 0.69;  val: loss =  0.85, acc = 0.68;  ||dEdTheta|| =  0.60
# 1100: eps = 9.89e-02;  batch: loss =  0.65, acc = 0.80;  train: loss =  0.86, acc = 0.67;  val: loss =  0.87, acc = 0.67;  ||dEdTheta|| =  0.42
# 1200: eps = 9.88e-02;  batch: loss =  0.51, acc = 0.80;  train: loss =  0.84, acc = 0.68;  val: loss =  0.83, acc = 0.69;  ||dEdTheta|| =  0.51
# 1300: eps = 9.87e-02;  batch: loss =  0.85, acc = 0.60;  train: loss =  0.77, acc = 0.73;  val: loss =  0.77, acc = 0.73;  ||dEdTheta|| =  0.58
# 1400: eps = 9.86e-02;  batch: loss =  0.65, acc = 0.80;  train: loss =  0.75, acc = 0.74;  val: loss =  0.76, acc = 0.73;  ||dEdTheta|| =  0.31
# 1500: eps = 9.85e-02;  batch: loss =  1.23, acc = 0.60;  train: loss =  0.73, acc = 0.75;  val: loss =  0.75, acc = 0.73;  ||dEdTheta|| =  1.10
# 1600: eps = 9.84e-02;  batch: loss =  0.63, acc = 0.80;  train: loss =  0.71, acc = 0.76;  val: loss =  0.74, acc = 0.74;  ||dEdTheta|| =  0.45
# 1700: eps = 9.83e-02;  batch: loss =  0.58, acc = 0.75;  train: loss =  0.68, acc = 0.76;  val: loss =  0.71, acc = 0.75;  ||dEdTheta|| =  0.54
# 1800: eps = 9.82e-02;  batch: loss =  0.53, acc = 0.90;  train: loss =  0.69, acc = 0.77;  val: loss =  0.71, acc = 0.76;  ||dEdTheta|| =  0.42
# 1900: eps = 9.81e-02;  batch: loss =  0.47, acc = 0.90;  train: loss =  0.70, acc = 0.76;  val: loss =  0.70, acc = 0.75;  ||dEdTheta|| =  0.53
# 2000: eps = 9.80e-02;  batch: loss =  0.47, acc = 0.85;  train: loss =  0.64, acc = 0.78;  val: loss =  0.66, acc = 0.77;  ||dEdTheta|| =  0.45

# %% [markdown]
# ## Visualize the training process with some plots

# %%
plt.figure(figsize=(10,5))
plt.plot(stats['batch_losss'],label='batch loss')
plt.plot(stats['check_its'],stats['train_losss'],label='train loss')
plt.plot(stats['check_its'],stats['val_losss'],label='val loss')
plt.xlabel('Iterations')
plt.legend()

plt.figure(figsize=(10,5))
plt.plot(stats['batch_accs'],label='batch acc')
plt.plot(stats['check_its'],stats['train_accs'],label='train acc')
plt.plot(stats['check_its'],stats['val_accs'],label='val acc')
plt.xlabel('Iterations')
plt.legend()

# %% [markdown]
# ## Compare training with different batch sizes

# %%
opt_params = { 'epsilon0':1e-1, 'epsilon_decay':0.99999,
               'num_its':2001, 'check_freq':100, 'print_checks':False, 'Theta0':None }
arch_params = { 'num_hidden_layers':2, 'num_hidden_units':20, 'num_outs':num_classes,
                'act_func':relu, 'out_func':softmax, 'loss_func':crossent }

batch_sz_vals = [2, 5, 20, 50]

for trial,batch_sz in enumerate(batch_sz_vals):
  opt_params['batch_sz'] = batch_sz

  # Make ~3 passes through the training data
  opt_params['num_its'] = (3*train_x.shape[0])//batch_sz
  opt_params['check_freq'] = 1000//batch_sz
  opt_params['epsilon_decay'] = (0.99999)**(5.0/batch_sz)
  Theta_t, stats_t = nn_fit(train_x, train_y, val_x, val_y,
                            opt_params, arch_params)

  # Plot the loss curves as a function of data points processed
  plt.figure(figsize=(10,5))
  plt.plot(stats_t['data_pts'],stats_t['batch_losss'],label='batch loss')
  plt.plot(stats_t['check_data_pts'],stats_t['train_losss'],label='train loss')
  plt.plot(stats_t['check_data_pts'],stats_t['val_losss'],label='val loss')
  plt.xlabel('Datapoints Processed ({} total)'.format(train_x.shape[0]))
  plt.ylim(0,2.5)
  plt.title('batch_sz = {}, best val loss = {:.2f}, best train loss = {:.2f}'.format(batch_sz,np.min(stats_t['val_losss']),np.min(stats_t['train_losss'])))
  plt.legend()

# %% [markdown]
# ## Compare training with different architectures

# %%
opt_params = { 'batch_sz':20, 'epsilon0':1e-1, 'epsilon_decay':0.99999,
               'num_its':2001, 'check_freq':100, 'print_checks':False, 'Theta0':None }
arch_params = { 'num_hidden_layers':2, 'num_outs':num_classes,
                'act_func':relu, 'out_func':softmax, 'loss_func':crossent }

hidden_units_vals = [5,10,20,100,200,400,600]
final_val_loss = []
final_train_loss = []
for trial,hidden_units in enumerate(hidden_units_vals):
  arch_params['num_hidden_units'] = hidden_units

  Theta_t, stats_t = nn_fit(train_x, train_y, val_x, val_y,
                            opt_params, arch_params)
  
  final_val_loss.append(np.min(stats_t['val_losss']))
  final_train_loss.append(np.min(stats_t['train_losss']))
  

# plot the best validation and training losses as functions of # of hidden units
plt.figure()
plt.plot(hidden_units_vals, final_train_loss, label='training')
plt.plot(hidden_units_vals, final_val_loss, label='validation')
plt.xlabel('Number of Hidden Units')
plt.title('Loss value')
plt.legend()

# %% [markdown]
# ## Do some hyperparameter architecture search
#
# Place any code you use to do hyperparameter search below here.  You may add extra code blocks if you want or need.

# %%
#notice: This cell takes 1 hour to accomplish!


opt_params = { 'batch_sz':20, 'epsilon0':1e-1, 'epsilon_decay':0.99999,
               'num_its':2001, 'check_freq':100, 'print_checks':False, 'Theta0':None }
arch_params = { 'num_hidden_layers':2, 'num_outs':num_classes,
                'act_func':relu, 'out_func':softmax, 'loss_func':crossent }



batch_sz_vals = [2, 5, 20]
epsilon0_vals = [1e-2, 5e-2, 1e-1]
check_freq: 200
epsilon_decay: 0.99999
hidden_units_vall = [5,10,20]
hidden_layerss = [1, 2, 3]

min_train_loss = 1000
min_val_loss = 1000
min_layer= 0
min_unit = 0
min_batch_sz = 0
min_epsilon = 0



hidden_units_vals = []
final_val_loss = []
final_train_loss = []
hidden_layers = []

for trial,hidden_layer in enumerate(hidden_layerss):
  for trial,hidden_units in enumerate(hidden_units_vall):
    for trail,batch_sz in enumerate(batch_sz_vals):
      for train,epsilon in enumerate(epsilon0_vals):
        arch_params['num_hidden_layers'] = hidden_layer
        arch_params['num_hidden_units'] = hidden_units
        opt_params['batch_sz'] = batch_sz
        opt_params['epsilon0'] = epsilon
        Theta_t, stats_t = nn_fit(train_x, train_y, val_x, val_y,
                            opt_params, arch_params)
  
        final_val_loss.append(np.min(stats_t['val_losss']))
        final_train_loss.append(np.min(stats_t['train_losss']))
        print('val_loss:{} train_loss:{} num_hidden_layers_vals:{} hidden_units_vals:{} batch_sz_vals:{} epsilon0_vals:{}'.format(np.min(stats_t['val_losss']),np.min(stats_t['train_losss'])
        ,hidden_layer,hidden_units,batch_sz,epsilon))

        if np.min(stats_t['val_losss'])<min_val_loss:
          min_val_loss = np.min(stats_t['val_losss'])
        if np.min(stats_t['train_losss']) < min_train_loss:
          min_layer= hidden_layer
          min_unit = hidden_units
          min_batch_sz = batch_sz
          min_epsilon = epsilon
          min_train_loss = min_val_loss
print('min_val_loss:{} min_train_loss:{} min_num_hidden_layers_vals:{} min_hidden_units_vals:{} min_batch_sz_vals:{} min_epsilon0_vals:{}'.format(min_val_loss,min_train_loss,min_layer
                                                                                                                                                  ,min_unit,min_batch_sz,min_epsilon))
# Out:
# val_loss:2.2635636899010607 train_loss:2.2575635444144373 num_hidden_layers_vals:1 hidden_units_vals:5 batch_sz_vals:2 epsilon0_vals:0.01
# val_loss:1.315415583574473 train_loss:1.3070462725770506 num_hidden_layers_vals:1 hidden_units_vals:5 batch_sz_vals:2 epsilon0_vals:0.05
# val_loss:1.2757327967763539 train_loss:1.2680636968118983 num_hidden_layers_vals:1 hidden_units_vals:5 batch_sz_vals:2 epsilon0_vals:0.1
# val_loss:2.2472727554669087 train_loss:2.2381971841548323 num_hidden_layers_vals:1 hidden_units_vals:5 batch_sz_vals:5 epsilon0_vals:0.01
# val_loss:1.4721731967127394 train_loss:1.449859825292406 num_hidden_layers_vals:1 hidden_units_vals:5 batch_sz_vals:5 epsilon0_vals:0.05
# val_loss:1.1539027042870236 train_loss:1.1435339582513735 num_hidden_layers_vals:1 hidden_units_vals:5 batch_sz_vals:5 epsilon0_vals:0.1
# val_loss:2.259354807197019 train_loss:2.2505661180825 num_hidden_layers_vals:1 hidden_units_vals:5 batch_sz_vals:20 epsilon0_vals:0.01
# val_loss:1.4365446226942316 train_loss:1.414420118904526 num_hidden_layers_vals:1 hidden_units_vals:5 batch_sz_vals:20 epsilon0_vals:0.05
# val_loss:1.121777568489871 train_loss:1.1043413957416433 num_hidden_layers_vals:1 hidden_units_vals:5 batch_sz_vals:20 epsilon0_vals:0.1
# val_loss:1.8516347971534353 train_loss:1.8282125788516361 num_hidden_layers_vals:1 hidden_units_vals:10 batch_sz_vals:2 epsilon0_vals:0.01
# val_loss:0.8518270643162984 train_loss:0.844464772356966 num_hidden_layers_vals:1 hidden_units_vals:10 batch_sz_vals:2 epsilon0_vals:0.05
# val_loss:0.7945306333859496 train_loss:0.7643963385203315 num_hidden_layers_vals:1 hidden_units_vals:10 batch_sz_vals:2 epsilon0_vals:0.1
# val_loss:1.834992895397152 train_loss:1.8115179272182125 num_hidden_layers_vals:1 hidden_units_vals:10 batch_sz_vals:5 epsilon0_vals:0.01
# val_loss:0.8001429778306246 train_loss:0.794390989810144 num_hidden_layers_vals:1 hidden_units_vals:10 batch_sz_vals:5 epsilon0_vals:0.05
# val_loss:0.6842215112712416 train_loss:0.6649245815528103 num_hidden_layers_vals:1 hidden_units_vals:10 batch_sz_vals:5 epsilon0_vals:0.1
# val_loss:1.8309698185351428 train_loss:1.8066191465145993 num_hidden_layers_vals:1 hidden_units_vals:10 batch_sz_vals:20 epsilon0_vals:0.01
# val_loss:0.7694017761724325 train_loss:0.7666173286353369 num_hidden_layers_vals:1 hidden_units_vals:10 batch_sz_vals:20 epsilon0_vals:0.05
# val_loss:0.6344500725276734 train_loss:0.6143908896653901 num_hidden_layers_vals:1 hidden_units_vals:10 batch_sz_vals:20 epsilon0_vals:0.1
# val_loss:1.6696916817878098 train_loss:1.6641242102073266 num_hidden_layers_vals:1 hidden_units_vals:20 batch_sz_vals:2 epsilon0_vals:0.01
# val_loss:0.8306412068334742 train_loss:0.8217910490120761 num_hidden_layers_vals:1 hidden_units_vals:20 batch_sz_vals:2 epsilon0_vals:0.05
# val_loss:0.7738424385304429 train_loss:0.7509413480410081 num_hidden_layers_vals:1 hidden_units_vals:20 batch_sz_vals:2 epsilon0_vals:0.1
# val_loss:1.6575142611220015 train_loss:1.6489527107710573 num_hidden_layers_vals:1 hidden_units_vals:20 batch_sz_vals:5 epsilon0_vals:0.01
# val_loss:0.7744360785593425 train_loss:0.7700603440621552 num_hidden_layers_vals:1 hidden_units_vals:20 batch_sz_vals:5 epsilon0_vals:0.05
# val_loss:0.6879080832465526 train_loss:0.6514654362425367 num_hidden_layers_vals:1 hidden_units_vals:20 batch_sz_vals:5 epsilon0_vals:0.1
# val_loss:1.6525463670166236 train_loss:1.640923622367965 num_hidden_layers_vals:1 hidden_units_vals:20 batch_sz_vals:20 epsilon0_vals:0.01
# val_loss:0.7469951983871689 train_loss:0.7364469289570217 num_hidden_layers_vals:1 hidden_units_vals:20 batch_sz_vals:20 epsilon0_vals:0.05
# val_loss:0.6024737230478825 train_loss:0.5778973034567858 num_hidden_layers_vals:1 hidden_units_vals:20 batch_sz_vals:20 epsilon0_vals:0.1
# val_loss:2.2973205051964203 train_loss:2.29676341529991 num_hidden_layers_vals:2 hidden_units_vals:5 batch_sz_vals:2 epsilon0_vals:0.01
# val_loss:2.0234742564079853 train_loss:2.0209979464730154 num_hidden_layers_vals:2 hidden_units_vals:5 batch_sz_vals:2 epsilon0_vals:0.05
# val_loss:1.7276365813736168 train_loss:1.7285255031155864 num_hidden_layers_vals:2 hidden_units_vals:5 batch_sz_vals:2 epsilon0_vals:0.1
# val_loss:2.297285703604881 train_loss:2.2970852067757113 num_hidden_layers_vals:2 hidden_units_vals:5 batch_sz_vals:5 epsilon0_vals:0.01
# val_loss:1.974309199990104 train_loss:1.9737205273926317 num_hidden_layers_vals:2 hidden_units_vals:5 batch_sz_vals:5 epsilon0_vals:0.05
# val_loss:1.5951109264625043 train_loss:1.606331171680013 num_hidden_layers_vals:2 hidden_units_vals:5 batch_sz_vals:5 epsilon0_vals:0.1
# val_loss:2.297449611772406 train_loss:2.2970485928830437 num_hidden_layers_vals:2 hidden_units_vals:5 batch_sz_vals:20 epsilon0_vals:0.01
# val_loss:1.9665555868636104 train_loss:1.9671314354192422 num_hidden_layers_vals:2 hidden_units_vals:5 batch_sz_vals:20 epsilon0_vals:0.05
# val_loss:1.5440177286069865 train_loss:1.556306576531078 num_hidden_layers_vals:2 hidden_units_vals:5 batch_sz_vals:20 epsilon0_vals:0.1
# val_loss:2.294741509749892 train_loss:2.294389871231578 num_hidden_layers_vals:2 hidden_units_vals:10 batch_sz_vals:2 epsilon0_vals:0.01
# val_loss:1.5479114913451972 train_loss:1.5326939944293563 num_hidden_layers_vals:2 hidden_units_vals:10 batch_sz_vals:2 epsilon0_vals:0.05
# val_loss:1.127968704713515 train_loss:1.1176406751617163 num_hidden_layers_vals:2 hidden_units_vals:10 batch_sz_vals:2 epsilon0_vals:0.1
# val_loss:2.294416700919354 train_loss:2.2945376763339476 num_hidden_layers_vals:2 hidden_units_vals:10 batch_sz_vals:5 epsilon0_vals:0.01
# val_loss:1.3537849986208579 train_loss:1.355153267145072 num_hidden_layers_vals:2 hidden_units_vals:10 batch_sz_vals:5 epsilon0_vals:0.05
# val_loss:0.934884741048153 train_loss:0.9483395593671331 num_hidden_layers_vals:2 hidden_units_vals:10 batch_sz_vals:5 epsilon0_vals:0.1
# val_loss:2.2944496607855007 train_loss:2.2941963152788967 num_hidden_layers_vals:2 hidden_units_vals:10 batch_sz_vals:20 epsilon0_vals:0.01
# val_loss:1.2808655127008026 train_loss:1.2856687625497132 num_hidden_layers_vals:2 hidden_units_vals:10 batch_sz_vals:20 epsilon0_vals:0.05
# val_loss:0.8404346901478779 train_loss:0.8490214800160643 num_hidden_layers_vals:2 hidden_units_vals:10 batch_sz_vals:20 epsilon0_vals:0.1
# val_loss:2.185752344513228 train_loss:2.1777256230637394 num_hidden_layers_vals:2 hidden_units_vals:20 batch_sz_vals:2 epsilon0_vals:0.01
# val_loss:0.9676492400398721 train_loss:0.9794858081980159 num_hidden_layers_vals:2 hidden_units_vals:20 batch_sz_vals:2 epsilon0_vals:0.05
# val_loss:0.8061151617993179 train_loss:0.811235916153158 num_hidden_layers_vals:2 hidden_units_vals:20 batch_sz_vals:2 epsilon0_vals:0.1
# val_loss:2.183240058086036 train_loss:2.1734217099136646 num_hidden_layers_vals:2 hidden_units_vals:20 batch_sz_vals:5 epsilon0_vals:0.01
# val_loss:0.9269240690576265 train_loss:0.9257559227519897 num_hidden_layers_vals:2 hidden_units_vals:20 batch_sz_vals:5 epsilon0_vals:0.05
# val_loss:0.7503988921112529 train_loss:0.7417175516044666 num_hidden_layers_vals:2 hidden_units_vals:20 batch_sz_vals:5 epsilon0_vals:0.1
# val_loss:2.180321138372153 train_loss:2.1709444145289014 num_hidden_layers_vals:2 hidden_units_vals:20 batch_sz_vals:20 epsilon0_vals:0.01
# val_loss:0.8314558059624844 train_loss:0.8301209356187196 num_hidden_layers_vals:2 hidden_units_vals:20 batch_sz_vals:20 epsilon0_vals:0.05
# val_loss:0.6552118853852676 train_loss:0.6328230976579093 num_hidden_layers_vals:2 hidden_units_vals:20 batch_sz_vals:20 epsilon0_vals:0.1
# val_loss:2.302221284290716 train_loss:2.302036516829891 num_hidden_layers_vals:3 hidden_units_vals:5 batch_sz_vals:2 epsilon0_vals:0.01
# val_loss:2.301914277903306 train_loss:2.3009117853210004 num_hidden_layers_vals:3 hidden_units_vals:5 batch_sz_vals:2 epsilon0_vals:0.05
# val_loss:2.296190332410432 train_loss:2.291986664427692 num_hidden_layers_vals:3 hidden_units_vals:5 batch_sz_vals:2 epsilon0_vals:0.1
# val_loss:2.302251278912761 train_loss:2.3018040653925524 num_hidden_layers_vals:3 hidden_units_vals:5 batch_sz_vals:5 epsilon0_vals:0.01
# val_loss:2.3022855073027984 train_loss:2.3006863390010293 num_hidden_layers_vals:3 hidden_units_vals:5 batch_sz_vals:5 epsilon0_vals:0.05
# val_loss:2.2960341742115276 train_loss:2.292966950728978 num_hidden_layers_vals:3 hidden_units_vals:5 batch_sz_vals:5 epsilon0_vals:0.1
# val_loss:2.302309656827594 train_loss:2.3017763401755467 num_hidden_layers_vals:3 hidden_units_vals:5 batch_sz_vals:20 epsilon0_vals:0.01
# val_loss:2.3020387673411773 train_loss:2.3002391441426275 num_hidden_layers_vals:3 hidden_units_vals:5 batch_sz_vals:20 epsilon0_vals:0.05
# val_loss:2.2944024769574596 train_loss:2.2913311578273046 num_hidden_layers_vals:3 hidden_units_vals:5 batch_sz_vals:20 epsilon0_vals:0.1
# val_loss:2.302013910541532 train_loss:2.301359561009266 num_hidden_layers_vals:3 hidden_units_vals:10 batch_sz_vals:2 epsilon0_vals:0.01
# val_loss:2.2988402058562505 train_loss:2.2955851247023333 num_hidden_layers_vals:3 hidden_units_vals:10 batch_sz_vals:2 epsilon0_vals:0.05
# val_loss:2.241051680716832 train_loss:2.235081106095018 num_hidden_layers_vals:3 hidden_units_vals:10 batch_sz_vals:2 epsilon0_vals:0.1
# val_loss:2.301799740002843 train_loss:2.301406357328302 num_hidden_layers_vals:3 hidden_units_vals:10 batch_sz_vals:5 epsilon0_vals:0.01
# val_loss:2.297887065530397 train_loss:2.2962671247419677 num_hidden_layers_vals:3 hidden_units_vals:10 batch_sz_vals:5 epsilon0_vals:0.05
# val_loss:2.2136341430870132 train_loss:2.2064727997172375 num_hidden_layers_vals:3 hidden_units_vals:10 batch_sz_vals:5 epsilon0_vals:0.1
# val_loss:2.3018630133038473 train_loss:2.301444938304106 num_hidden_layers_vals:3 hidden_units_vals:10 batch_sz_vals:20 epsilon0_vals:0.01
# val_loss:2.2982657781354114 train_loss:2.296000781799265 num_hidden_layers_vals:3 hidden_units_vals:10 batch_sz_vals:20 epsilon0_vals:0.05
# val_loss:2.223993317458328 train_loss:2.2149008484376855 num_hidden_layers_vals:3 hidden_units_vals:10 batch_sz_vals:20 epsilon0_vals:0.1
# val_loss:2.277739455132632 train_loss:2.273431431632312 num_hidden_layers_vals:3 hidden_units_vals:20 batch_sz_vals:2 epsilon0_vals:0.01
# val_loss:1.2322798062660676 train_loss:1.2304123628673005 num_hidden_layers_vals:3 hidden_units_vals:20 batch_sz_vals:2 epsilon0_vals:0.05
# val_loss:0.9745052789342662 train_loss:0.9908047528377867 num_hidden_layers_vals:3 hidden_units_vals:20 batch_sz_vals:2 epsilon0_vals:0.1
# val_loss:2.2777188597486293 train_loss:2.274523990540305 num_hidden_layers_vals:3 hidden_units_vals:20 batch_sz_vals:5 epsilon0_vals:0.01
# val_loss:1.1579363763243842 train_loss:1.1563965639113165 num_hidden_layers_vals:3 hidden_units_vals:20 batch_sz_vals:5 epsilon0_vals:0.05
# val_loss:0.9388617543357939 train_loss:0.9196368090798382 num_hidden_layers_vals:3 hidden_units_vals:20 batch_sz_vals:5 epsilon0_vals:0.1
# val_loss:2.2784782515811126 train_loss:2.2745587057114927 num_hidden_layers_vals:3 hidden_units_vals:20 batch_sz_vals:20 epsilon0_vals:0.01
# val_loss:1.0039538842009983 train_loss:1.021985509768886 num_hidden_layers_vals:3 hidden_units_vals:20 batch_sz_vals:20 epsilon0_vals:0.05
# val_loss:0.7746362736631383 train_loss:0.7774496514564649 num_hidden_layers_vals:3 hidden_units_vals:20 batch_sz_vals:20 epsilon0_vals:0.1
# min_val_loss:0.6024737230478825 min_train_loss:0.6024737230478825 min_num_hidden_layers_vals:1 min_hidden_units_vals:20 min_batch_sz_vals:20 min_epsilon0_vals:0.1

# %%
# num_hidden_units ： 200
opt_params = { 'batch_sz':5, 'epsilon0':1e-1, 'epsilon_decay':0.99999,
               'num_its':2001, 'check_freq':100, 'print_checks':False, 'Theta0':None }
arch_params = { 'num_hidden_units':200, 'num_outs':num_classes,
                'act_func':relu, 'out_func':softmax, 'loss_func':crossent }

num_hidden_layers_vals = [1, 2, 3]
final_val_acc = []
avg_val_loss = []
final_train_acc = []
avg_train_loss = []

for trial, num_hidden_layer in enumerate(num_hidden_layers_vals):
  arch_params['num_hidden_layers'] = num_hidden_layer
  # Make ~3 passes through the training data
  Theta_t, stats_t = nn_fit(train_x, train_y, val_x, val_y,
                            opt_params, arch_params)
  final_val_acc.append(stats_t['val_accs'][-1])
  final_train_acc.append(stats_t['train_accs'][-1])
  avg_val_loss.append(np.average(stats_t['val_losss']))
  avg_train_loss.append(np.average(stats_t['train_losss']))
  # Plot the loss curves as a function of data points processed

plt.figure(figsize=(10,5))
plt.plot(num_hidden_layers_vals,final_val_acc,label='val acc')
plt.plot(num_hidden_layers_vals,avg_val_loss,label='val loss')
plt.plot(num_hidden_layers_vals,final_train_acc,label='train acc')
plt.plot(num_hidden_layers_vals,avg_train_loss,label='train loss')
plt.xlabel('number of hidden layers')
plt.legend()
print("Highest accuracy: {} at 'number of hidden layers {}".format(np.max(final_val_acc), num_hidden_layers_vals[np.argmax(final_val_acc)]))
print("val_acc_avg:{} val_loss_avg:{}".format(np.average(final_val_acc),np.average(avg_val_loss)))
print("train_acc_avg:{} train_loss_avg:{}".format(np.average(final_train_acc),np.average(avg_train_loss)))
# Out:
# Highest accuracy: 0.8117857142857143 at 'number of hidden layers 2
# val_acc_avg:0.7882142857142856 val_loss_avg:0.8787590039527222
# train_acc_avg:0.8076587301587302 train_loss_avg:0.8517232996634684

# %%
# num_hidden_layers ： 2
opt_params = { 'batch_sz':5, 'epsilon0':1e-1, 'epsilon_decay':0.99999,
               'num_its':2001, 'check_freq':100, 'print_checks':False, 'Theta0':None }
arch_params = { 'num_hidden_layers':2, 'num_outs':num_classes,
                'act_func':relu, 'out_func':softmax, 'loss_func':crossent }

hidden_units_vals = [100,200,300,400,500,600]
final_val_acc = []
avg_val_loss = []
final_train_acc = []
avg_train_loss = []

for trial, num_hidden_units in enumerate(hidden_units_vals):
  arch_params['num_hidden_units'] = num_hidden_units
  # Make ~3 passes through the training data
  Theta_t, stats_t = nn_fit(train_x, train_y, val_x, val_y,
                            opt_params, arch_params)
  final_val_acc.append(stats_t['val_accs'][-1])
  final_train_acc.append(stats_t['train_accs'][-1])
  avg_val_loss.append(np.average(stats_t['val_losss']))
  avg_train_loss.append(np.average(stats_t['train_losss']))
  # Plot the loss curves as a function of data points processed

plt.figure(figsize=(10,5))
plt.plot(hidden_units_vals,final_val_acc,label='val acc')
plt.plot(hidden_units_vals,avg_val_loss,label='val loss')
plt.plot(hidden_units_vals,final_train_acc,label='train acc')
plt.plot(hidden_units_vals,avg_train_loss,label='train loss')
plt.xlabel('number of hidden_units_vals')
plt.legend()
print("Highest accuracy: {} at 'number of hidden layers {}".format(np.max(final_val_acc), hidden_units_vals[np.argmax(final_val_acc)]))
print("val_acc_avg:{} val_loss_avg:{}".format(np.average(final_val_acc),np.average(avg_val_loss)))
print("train_acc_avg:{} train_loss_avg:{}".format(np.average(final_train_acc),np.average(avg_train_loss)))
# Out:
# Highest accuracy: 0.8008928571428572 at 'number of hidden layers 300
# val_acc_avg:0.7815178571428572 val_loss_avg:1.3901512618254799
# train_acc_avg:0.8010515873015874 train_loss_avg:1.346417468694897

# %%
# num_hidden_units ： 300
# num_hidden_layers': 2
opt_params = { 'epsilon0':1e-1, 'epsilon_decay':0.99999,
               'num_its':2001, 'check_freq':100, 'print_checks':False, 'Theta0':None }
arch_params = { 'num_hidden_layers':2, 'num_hidden_units':300, 'num_outs':num_classes,
                'act_func':relu, 'out_func':softmax, 'loss_func':crossent }

batch_sz_vals = [2, 5, 20, 50]
final_val_acc = []
avg_val_loss = []
final_train_acc = []
avg_train_loss = []
for trial,batch_sz in enumerate(batch_sz_vals):
  opt_params['batch_sz'] = batch_sz

  # Make ~3 passes through the training data
  opt_params['num_its'] = (3*train_x.shape[0])//batch_sz
  opt_params['check_freq'] = 1000//batch_sz
  opt_params['epsilon_decay'] = (0.99999)**(5.0/batch_sz)
  Theta_t, stats_t = nn_fit(train_x, train_y, val_x, val_y,
                            opt_params, arch_params)
  final_val_acc.append(stats_t['val_accs'][-1])
  final_train_acc.append(stats_t['train_accs'][-1])
  avg_val_loss.append(np.average(stats_t['val_losss']))
  avg_train_loss.append(np.average(stats_t['train_losss']))
  # Plot the loss curves as a function of data points processed

plt.figure(figsize=(10,5))
plt.plot(batch_sz_vals,final_val_acc,label='val acc')
plt.plot(batch_sz_vals,avg_val_loss,label='val loss')
plt.plot(batch_sz_vals,final_train_acc,label='train acc')
plt.plot(batch_sz_vals,avg_train_loss,label='train loss')
plt.xlabel('number of batch_sz_vals')
plt.legend()
print("Highest accuracy: {} at 'number of batch_sz_vals {}".format(np.max(final_val_acc), batch_sz_vals[np.argmax(final_val_acc)]))
print("val_acc_avg:{} val_loss_avg:{}".format(np.average(final_val_acc),np.average(avg_val_loss)))
print("train_acc_avg:{} train_loss_avg:{}".format(np.average(final_train_acc),np.average(avg_train_loss)))
# Out:
# Highest accuracy: 0.83375 at 'number of batch_sz_vals 5
# val_acc_avg:0.8216517857142858 val_loss_avg:0.787015627306855
# train_acc_avg:0.852202380952381 train_loss_avg:0.7311617584323448

# %%
# batch_sz : 5
# num_hidden_units ： 300
# num_hidden_layers': 2
# check_freq: 200
# epsilon_decay: 0.99999
opt_params = { 'batch_sz':5, 'epsilon0':1e-1, 'epsilon_decay':0.99999,
               'num_its':2001, 'check_freq':200, 'print_checks':False, 'Theta0':None }
arch_params = { 'num_hidden_layers':2, 'num_hidden_units':300, 'num_outs':num_classes,
                'act_func':relu, 'out_func':softmax, 'loss_func':crossent }

epsilon0_vals = [1e-2, 5e-2, 1e-1, 2e-1, 5e-1]
final_val_acc = []
avg_val_loss = []
final_train_acc = []
avg_train_loss = []
for trial,epsilon0 in enumerate(epsilon0_vals):
  opt_params['epsilon0'] = epsilon0
  Theta_t, stats_t = nn_fit(train_x, train_y, val_x, val_y,
                            opt_params, arch_params)
  final_val_acc.append(stats_t['val_accs'][-1])
  final_train_acc.append(stats_t['train_accs'][-1])
  avg_val_loss.append(np.average(stats_t['val_losss']))
  avg_train_loss.append(np.average(stats_t['train_losss']))
  # Plot the loss curves as a function of data points processed

plt.figure(figsize=(10,5))
plt.plot(epsilon0_vals,final_val_acc,label='val acc')
plt.plot(epsilon0_vals,avg_val_loss,label='val loss')
plt.plot(epsilon0_vals,final_train_acc,label='train acc')
plt.plot(epsilon0_vals,avg_train_loss,label='train loss')
plt.xlabel('epsilon0')
plt.legend()
print("Highest accuracy: {} at 'number of epsilon0 {}".format(np.max(final_val_acc), epsilon0_vals[np.argmax(final_val_acc)]))
print("val_acc_avg:{} val_loss_avg:{}".format(np.average(final_val_acc),np.average(avg_val_loss)))
print("train_acc_avg:{} train_loss_avg:{}".format(np.average(final_train_acc),np.average(avg_train_loss)))
# Out:
# Highest accuracy: 0.8126785714285715 at 'number of epsilon0 0.1
# val_acc_avg:0.7749285714285714 val_loss_avg:1.2050620563134147
# train_acc_avg:0.7969999999999999 train_loss_avg:1.1677391262962236

# %%
# batch_sz : 5
# num_hidden_units ： 300
# num_hidden_layers : 2
# epsilon0 : 0.1
# epsilon_decay : 0.99999

opt_params = { 'batch_sz':5, 'epsilon0':5e-2, 'epsilon_decay': 0.99999,
               'num_its': 7001, 'check_freq':200, 'print_checks':False, 'Theta0':None }
arch_params = { 'num_hidden_layers':2, 'num_hidden_units':300, 'num_outs':num_classes,
                'act_func':relu, 'out_func':softmax, 'loss_func':crossent }

avg_val_loss = []
Theta_t, stats_t = nn_fit(train_x, train_y, val_x, val_y,
                            opt_params, arch_params)
final_val_acc = stats_t['val_accs']
# Plot the loss curves as a function of data points processed

plt.figure(figsize=(10,5))
plt.plot(stats_t['check_its'],final_val_acc,label='val acc')
plt.plot(stats_t['check_its'],stats_t['train_accs'],label='train acc')
plt.plot(stats_t['check_its'],stats_t['val_losss'],label='val loss')
plt.xlabel('# iterations on val')
plt.legend()
print("Highest accuracy: {} at iteration {}".format(np.max(final_val_acc), stats_t['check_its'][np.argmax(final_val_acc)]))
# Out:
# Highest accuracy: 0.8357142857142857 at iteration 5800
